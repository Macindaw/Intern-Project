# %% [markdown]
# <a href="https://colab.research.google.com/github/Macindaw/Intern-Project/blob/main/Reporduce_Graphs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This Notebook will be about reproducing the graphs on the learning at pawsey webpage.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

s_data = pd.read_csv('surveydata.csv')
s_data
# Out:
#                Timestamp  ... How often do I go to bed and worry about things happening at home or at school?
# 0    01/06/2021 07:24:37  ...                                                2.0
# 1    07/06/2021 23:33:43  ...                                                NaN
# 2    08/06/2021 07:49:50  ...                                                NaN
# 3    08/06/2021 08:12:38  ...                                                NaN
# 4    08/06/2021 08:14:37  ...                                                3.0
# ..                   ...  ...                                                ...
# 710  26/11/2021 04:20:27  ...                                                3.0
# 711  26/11/2021 04:24:09  ...                                                NaN
# 712  26/11/2021 04:27:42  ...                                                0.0
# 713  26/11/2021 04:48:08  ...                                                3.0
# 714  26/11/2021 05:56:17  ...                                                2.0
#
# [715 rows x 51 columns]

# %%
data_bar = s_data["How rested or refreshed do you feel when you wake up for the day?"]
x_val = data_bar.unique()
x_val = np.sort(x_val)
data_bar = data_bar.value_counts(sort=False) #Extracts amount of responses per category
y_val = data_bar.to_numpy()

x_val

sns.set_theme(style="whitegrid")
f, ax =  plt.subplots(figsize=(6,15))

sns.set_color_codes("pastel")
sns.barplot(x=x_val, y=y_val)

# %%
data_bar = s_data["How rested or refreshed do you feel when you wake up for the day?"]
# data_bar["How rested or refreshed do you feel when you wake up for the day?"].reset

sns.set_theme(style="darkgrid")
ax = sns.countplot(y="How rested or refreshed do you feel when you wake up for the day?", data=s_data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-6131fac8f141> in <module>()
#       4 sns.set_theme(style="darkgrid")
#       5 ax = sns.countplot(y="How rested or refreshed do you feel when you wake up for the day?", data=s_data)
# ----> 6 ax.bar_label(ax.containers[0])
#
# AttributeError: 'AxesSubplot' object has no attribute 'bar_label'

# %% [markdown]
# **Histograms**

# %%
s_data = pd.read_csv('surveydata.csv')

#Step 1 Localise the data
title_data = "How rested or refreshed do you feel when you wake up for the day?"
data_bar = s_data[title_data] #Note When Using How - usualy categorical data from 1-5, what is usaully some other type
frequency = data_bar.value_counts(sort=False).to_numpy() #Extracts the frequncy of responses per category
ypos =  np.arange(len(frequency)) #Automatically assigns indexs for each number in the data

temp = data_bar.unique() #Extracted range of different rows
temp = np.sort(temp)  #Sorting Range into order

plt.xticks(ypos, temp)  #Adding these labels back
plt.xlabel("Rating (Out of 5)")
plt.ylabel("Number of Responses")
plt.title(title_data)

# plt.text(0, frequency[0], frequency[0], ha='center', va = 'bottom')
for i in range(len(frequency)): #Adding Labels to the Graph
  plt.text(i, frequency[i], frequency[i], ha='center', va = 'bottom')

plt.bar(ypos, frequency) #Graphs the Histogram
# Out:
# [111 173 248 150  33]
# <BarContainer object of 5 artists>

# %%
plt.yticks(ypos, temp)  #Adding these labels back
plt.ylabel("Rating (Out of 5)")
plt.xlabel("Number of Responses")
plt.title(title_data)
plt.barh(ypos, frequency) #Graphs the Histogram
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-a62059c50b83> in <module>()
#       4 plt.title(title_data)
#       5 plt.barh(ypos, frequency) #Graphs the Histogram
# ----> 6 plt.text(0,y[0], "Test")
#
# NameError: name 'y' is not defined

# %%
fig, ax = plt.subplots()
hbars = ax.barh(ypos, frequency, align='center')

ax.set_yticks(ticks=ypos) #Note if you coppy tuts on line they have changed this so it needs to be done in two lines
ax.set_yticklabels(temp)
ax.invert_yaxis()
ax.set_xlabel("Rating (Out of 5)")
ax.set_title(title_data)


plt.show
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-ee149ade8e60> in <module>()
#       7 ax.set_xlabel("Rating (Out of 5)")
#       8 ax.set_title(title_data)
# ----> 9 ax.bar_label(hbars, label_type='center')
#      10
#      11 plt.show
#
# AttributeError: 'AxesSubplot' object has no attribute 'bar_label'

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)


plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
people = ('Tom', 'Dick', 'Harry', 'Slim', 'Jim')
y_pos = np.arange(len(people))
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

ax.barh(y_pos, performance, xerr=error, align='center')
ax.set_xticks(y_pos, labels=people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Performance')
ax.set_title('How fast do you want to go today?')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-6e4c59a5823c> in <module>()
#      16
#      17 ax.barh(y_pos, performance, xerr=error, align='center')
# ---> 18 ax.set_xticks(y_pos, labels=people)
#      19 ax.invert_yaxis()  # labels read top-to-bottom
#      20 ax.set_xlabel('Performance')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     391     @functools.wraps(func)
#     392     def wrapper(*args, **kwargs):
# --> 393         bound = signature.bind(*args, **kwargs)
#     394         if name in bound.arguments and name not in kwargs:
#     395             warn_deprecated(
#
# /usr/lib/python3.7/inspect.py in bind(*args, **kwargs)
#    3013         if the passed arguments can not be bound.
#    3014         """
# -> 3015         return args[0]._bind(args[1:], kwargs)
#    3016
#    3017     def bind_partial(*args, **kwargs):
#
# /usr/lib/python3.7/inspect.py in _bind(self, args, kwargs, partial)
#    3004                 raise TypeError(
#    3005                     'got an unexpected keyword argument {arg!r}'.format(
# -> 3006                         arg=next(iter(kwargs))))
#    3007
#    3008         return self._bound_arguments_cls(self, arguments)
#
# TypeError: got an unexpected keyword argument 'labels'
